# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Feature Scaling Based on Variance

# %%
data = pd.read_csv("Data/archive/winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
features = data.drop(['quality'],axis=1)
labels = data.filter(['quality'],axis=1)

# %%
features.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
features.var()
# Out:
# fixed acidity              3.031416
# volatile acidity           0.032062
# citric acid                0.037947
# residual sugar             1.987897
# chlorides                  0.002215
# free sulfur dioxide      109.414884
# total sulfur dioxide    1082.102373
# density                    0.000004
# pH                         0.023835
# sulphates                  0.028733
# alcohol                    1.135647
# dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold

var_Sel = VarianceThreshold(threshold=(0.1))
var_Sel.fit(features)
# Out:
# VarianceThreshold(threshold=0.1)

# %%
attributes_to_retain = features.columns[var_Sel.get_support()]
attributes_to_retain
# Out:
# Index(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol'],
#       dtype='object')

# %%
attributes_to_filter = [attr for attr in features.columns if attr not in features.columns[var_Sel.get_support()]]
attributes_to_filter
# Out:
# ['volatile acidity', 'citric acid', 'chlorides', 'density', 'pH', 'sulphates']

# %% [markdown]
# ## Note
# One of the main issues with variance-based feature selection is that it doesn’t take the relationship between mutual features into account while feature selection. Hence, with variance- based feature selection, redundant features may be selected.

# %% [markdown]
# # Feature Selection using Correlation
#
# In feature selection based on correlation, the features are selected using the following steps: <br>
# 1. Mutual correlation between all the features is calculated.
# 2. The correlation threshold is set.
# 3. Features having mutual correlation greater than the correlation threshold with any other feature are removed from the dataset

# %%
correlation_matrix = features.corr()
correlation_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
#
#                        alcohol
# fixed acidity        -0.061668
# volatile acidity     -0.202288
# citric acid           0.109903
# residual sugar        0.042075
# chlorides            -0.221141
# free sulfur dioxide  -0.069408
# total sulfur dioxide -0.205654
# density              -0.496180
# pH                    0.205633
# sulphates             0.093595
# alcohol               1.000000

# %%
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0e282_row0_col0, #T_0e282_row1_col1, #T_0e282_row2_col2, #T_0e282_row3_col3, #T_0e282_row4_col4, #T_0e282_row5_col5, #T_0e282_row6_col6, #T_0e282_row7_col7, #T_0e282_row8_col8, #T_0e282_row9_col9, #T_0e282_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col1, #T_0e282_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col3, #T_0e282_row4_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_0e282_row0_col5, #T_0e282_row0_col8, #T_0e282_row1_col2, #T_0e282_row1_col9, #T_0e282_row2_col1, #T_0e282_row7_col10, #T_0e282_row8_col0, #T_0e282_row8_col3, #T_0e282_row8_col4, #T_0e282_row10_col6, #T_0e282_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_0e282_row0_col9, #T_0e282_row3_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_0e282_row0_col10 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_0e282_row1_col0, #T_0e282_row3_col4, #T_0e282_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_0e282_row1_col3, #T_0e282_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0e282_row1_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_0e282_row1_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_0e282_row1_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0e282_row1_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_0e282_row1_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_0e282_row1_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_0e282_row2_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_0e282_row2_col3, #T_0e282_row3_col9, #T_0e282_row5_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_0e282_row2_col4, #T_0e282_row7_col1, #T_0e282_row7_col4, #T_0e282_row10_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_0e282_row2_col6, #T_0e282_row7_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0e282_row2_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_0e282_row2_col8, #T_0e282_row9_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0e282_row2_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0e282_row2_col10, #T_0e282_row6_col1, #T_0e282_row7_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_0e282_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_0e282_row3_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_0e282_row3_col2, #T_0e282_row5_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_0e282_row3_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_0e282_row3_col6, #T_0e282_row6_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_0e282_row3_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_0e282_row3_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_0e282_row4_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_0e282_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_0e282_row4_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_0e282_row4_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0e282_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_0e282_row4_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_0e282_row4_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_0e282_row4_col8, #T_0e282_row5_col9, #T_0e282_row6_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_0e282_row4_col9, #T_0e282_row9_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_0e282_row5_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0e282_row5_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0e282_row5_col2, #T_0e282_row5_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_0e282_row5_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_0e282_row5_col10, #T_0e282_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_0e282_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0e282_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_0e282_row6_col5 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_0e282_row6_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_0e282_row6_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0e282_row6_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_0e282_row6_col10, #T_0e282_row8_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0e282_row7_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_0e282_row7_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_0e282_row7_col5, #T_0e282_row8_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_0e282_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_0e282_row7_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_0e282_row8_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_0e282_row8_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0e282_row8_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_0e282_row8_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_0e282_row8_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_0e282_row9_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_0e282_row9_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_0e282_row9_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_0e282_row9_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_0e282_row9_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_0e282_row9_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_0e282_row10_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_0e282_row10_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_0e282_row10_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0e282_row10_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_0e282_row10_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_0e282_row10_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_0e282_row10_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# </style>
# <table id="T_0e282">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e282_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_0e282_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_0e282_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_0e282_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_0e282_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_0e282_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_0e282_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_0e282_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_0e282_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_0e282_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_0e282_level0_col10" class="col_heading level0 col10" >alcohol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e282_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_0e282_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0e282_row0_col1" class="data row0 col1" >-0.256131</td>
#       <td id="T_0e282_row0_col2" class="data row0 col2" >0.671703</td>
#       <td id="T_0e282_row0_col3" class="data row0 col3" >0.114777</td>
#       <td id="T_0e282_row0_col4" class="data row0 col4" >0.093705</td>
#       <td id="T_0e282_row0_col5" class="data row0 col5" >-0.153794</td>
#       <td id="T_0e282_row0_col6" class="data row0 col6" >-0.113181</td>
#       <td id="T_0e282

# %%
# another way to do same thing using seaborn
sns.heatmap(correlation_matrix,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
correlated_feature_matrix = set()

for i in range(len(correlation_matrix)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i,j])>0.6:
            corr_col = correlation_matrix.columns[i]
            correlated_feature_matrix.add(corr_col)

# %%
len(correlated_feature_matrix)
# Out:
# 4

# %%
correlated_feature_matrix
# Out:
# {'citric acid', 'density', 'pH', 'total sulfur dioxide'}

# %%
filtered_data = features.drop(correlated_feature_matrix,axis=1)
filtered_data.head()
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4              0.70             1.9      0.076
# 1            7.8              0.88             2.6      0.098
# 2            7.8              0.76             2.3      0.092
# 3           11.2              0.28             1.9      0.075
# 4            7.4              0.70             1.9      0.076
#
#    free sulfur dioxide  sulphates  alcohol
# 0                 11.0       0.56      9.4
# 1                 25.0       0.68      9.8
# 2                 15.0       0.65      9.8
# 3                 17.0       0.58      9.8
# 4                 11.0       0.56      9.4

# %% [markdown]
# # Feature Selection Based on Recursive Elimination
# In recursive feature elimination (RFE), a machine learning model is trained to make predictions. The predictions are compared with actual labels, and the predictive power of each feature is calculated. The feature with the least predictive power is eliminated
#
# The model is again trained, and in the second iteration, again, one feature with the least predictive power is eliminated. The process continues until a minimum number of features is achieved

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

lr = LinearRegression()
rfe = RFE(estimator=lr,n_features_to_select=4,step=1)
rfe.fit(features,labels)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=4)

# %%
rfe.ranking_
# Out:
# array([5, 1, 4, 6, 1, 7, 8, 1, 2, 1, 3])

# %%
attributes_to_retain = rfe.get_support(1)
attributes_to_retain
# Out:
# array([1, 4, 7, 9], dtype=int64)

# %%
filtered_data = features[features.columns[attributes_to_retain]]
filtered_data
# Out:
#       volatile acidity  chlorides  density  sulphates
# 0                0.700      0.076  0.99780       0.56
# 1                0.880      0.098  0.99680       0.68
# 2                0.760      0.092  0.99700       0.65
# 3                0.280      0.075  0.99800       0.58
# 4                0.700      0.076  0.99780       0.56
# ...                ...        ...      ...        ...
# 1594             0.600      0.090  0.99490       0.58
# 1595             0.550      0.062  0.99512       0.76
# 1596             0.510      0.076  0.99574       0.75
# 1597             0.645      0.075  0.99547       0.71
# 1598             0.310      0.067  0.99549       0.66
#
# [1599 rows x 4 columns]

# %% [markdown]
# # 4. Selection Based on Model Performance

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(features,labels)
# Out:
# C:\Users\ENVY\AppData\Local\Temp\ipykernel_20688\1332110296.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(features,labels)
# RandomForestRegressor()

# %%
model = SelectFromModel(rfr,prefit=True, threshold='mean')
X_transformed = model.transform(features)
# Out:
# c:\Users\ENVY\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
cols = model.get_support(indices=True)
cols
# Out:
# array([ 1,  9, 10], dtype=int64)

# %%
attributes_to_retain = features[features.columns[cols]]
attributes_to_retain
# Out:
#       volatile acidity  sulphates  alcohol
# 0                0.700       0.56      9.4
# 1                0.880       0.68      9.8
# 2                0.760       0.65      9.8
# 3                0.280       0.58      9.8
# 4                0.700       0.56      9.4
# ...                ...        ...      ...
# 1594             0.600       0.58     10.5
# 1595             0.550       0.76     11.2
# 1596             0.510       0.75     11.0
# 1597             0.645       0.71     10.2
# 1598             0.310       0.66     11.0
#
# [1599 rows x 3 columns]
